# %%
bio_data = {
    'Name':[],
    'Gender':[],
    'Date_of_birth':[],
    'Home_Address':[],
    'Phone_number':[],
    'Nationality':[],
    'Email_Address':[],
    'Institution':[],
    'Degree':[],
    'Course_of_study':[],
    'Core_skills':[],
    'Work_Experience':[],
    'Languages':[]
}

Name = input('Enter your name: ')
bio_data['Name'].append(Name)

Gender = input('Enter your gender: ')
if Gender == 'Female':
    print('F')
elif Gender == 'Male':
    print('M')
else:
    print('invalid,try again')
    Gender = input('Enter your gender: ')
bio_data['Gender'].append(Gender)

Date_of_birth = input('Enter your date_of_birth: ')
bio_data['Date_of_birth'].append(Date_of_birth)

Home_Address = input('Enter your home_address: ')
bio_data['Home_Address'].append(Home_Address)

Phone_number = input('Enter your Phone number: ')
while True:
    if Phone_number.isdigit() and len(Phone_number) == 11:
        break
    else:
        print('Invalid, try again')
        Phone_number = input('Enter your Phone number: ')
bio_data['Phone_number'].append(Phone_number)

Nationality = input('Enter your nationality: ')
bio_data['Nationality'].append(Nationality)

Email_Address = input('Enter your email_ address: ')
bio_data['Email_Address'].append(Email_Address)

Institution = input('Enter your institution: ')
bio_data['Institution'].append(Institution)

Degree = input('Enter your degree: ')
bio_data['Degree'].append(Degree)

Course_of_study = input('Enter your course of study: ')
bio_data['Course_of_study'].append(Course_of_study)

Work_Experience = input('Enter your work_experience: ')
bio_data['Work_Experience'].append(Work_Experience)

Core_skills = input('Enter your core_skills: ')
bio_data['Core_skills'].append(Core_skills)
    
Languages = input('Enter your language: ')
bio_data['Languages'].append(Languages)
    
print(f""" {Name}                                                              {Email_Address}
""")

print(f""" {Work_Experience}                                                   {Phone_number}
""")

print(f""" i'm a Results-driven {Work_Experience} with experience in in data analytics, machine learning, and statistical modeling. Proficient in Python, 
with expertise in predictive modeling and data visualization, committed to delivering actionable insights and optimizing business performance.
""")

print('WORK EXPERIENCE')

print(f""" {Work_Experience}
""")

print('CORE SKILLS')

print(f""" {Core_skills}
""")

print('EDUCATION')

print(f"""{Institution}
""")

print(f"""{Degree}                                                        {Course_of_study}
""")

print('LANGUAGES')

print(f"""{Languages}
""")
# Out:
# Enter your name: OLADIMEJI MARY
# Enter your gender: Female
# F
# Enter your date_of_birth: 15-01-1999
# Enter your home_address: No 24, Kobiowu street, Ibadan, Oyo State
# Enter your Phone number: 09066579939
# Enter your nationality: Nigeria
# Enter your email_ address: maryfavour783@gmail.com
# Enter your institution: Ladoke Akintola University Of Technology
# Enter your degree: Bachelor Of Technology
# Enter your course of study: Pure And Applied Mathematiscs
# Enter your work_experience: Data Scientist
# Enter your core_skills: python, data science, machine learning, data visualization, mathematics
# Enter your language: English
#  OLADIMEJI MARY                                                              maryfavour783@gmail.com
#
#  Data Scientist                                                   09066579939
#
#  i'm a Results-driven Data Scientist with experience in in data analytics, machine learning, and statistical modeling. Proficient in Python,
# ...
